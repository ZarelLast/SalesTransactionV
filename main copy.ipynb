# %% [markdown]
# # Install Libraries

# %%
# !pip install scikit-learn
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install
# Out:
# Requirement already satisfied: scikit-learn in .\env\lib\site-packages (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in .\env\lib\site-packages (from scikit-learn) (1.26.1)
# Requirement already satisfied: scipy>=1.5.0 in .\env\lib\site-packages (from scikit-learn) (1.11.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in .\env\lib\site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: joblib>=1.1.1 in .\env\lib\site-packages (from scikit-learn) (1.3.2)
# WARNING: You are using pip version 20.2.3; however, version 23.3.1 is available.
# You should consider upgrading via the 'd:\an-online-shop-business\env\scripts\python.exe -m pip install --upgrade pip' command.
# Collecting pandas
#   Downloading pandas-2.1.1-cp39-cp39-win_amd64.whl (10.8 MB)
# Requirement already satisfied: numpy>=1.22.4; python_version < "3.11" in .\env\lib\site-packages (from pandas) (1.26.1)
# Collecting pytz>=2020.1
#   Downloading pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\env\lib\site-packages (from pandas) (2.8.2)
# Collecting tzdata>=2022.1
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# Requirement already satisfied: six>=1.5 in .\env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.1.1 pytz-2023.3.post1 tzdata-2023.3
# WARNING: You are using pip version 20.2.3; however, version 23.3.1 is available.
# You should consider upgrading via the 'd:\an-online-shop-business\env\scripts\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# # Importing Libraries

# %%
import sklearn
from sklearn.linear_model import LinearRegression

# Importing for Data Manipulation
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Importing For Data Visualization
import matplotlib.pyplot as plt # for data visualization
import seaborn as sns
from wordcloud import WordCloud
import plotly.express as px
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\an-online-shop-business\main.ipynb Cell 5 line 3
#       <a href='vscode-notebook-cell:/d%3A/an-online-shop-business/main.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> # Importing for Data Manipulation
#       <a href='vscode-notebook-cell:/d%3A/an-online-shop-business/main.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> import numpy as np # linear algebra
# ----> <a href='vscode-notebook-cell:/d%3A/an-online-shop-business/main.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
#       <a href='vscode-notebook-cell:/d%3A/an-online-shop-business/main.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> # Importing For Data Visualization
#       <a href='vscode-notebook-cell:/d%3A/an-online-shop-business/main.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a> import matplotlib.pyplot as plt # for data visualization
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# # Reading The Dataset

# %%
# Reading the dataset with Pandas
df = pd.read_csv("./Sales Transaction v.4a.csv")

# Sampling the data based on heads (5 top ranks)
df.head()
# Out:
#   TransactionNo       Date ProductNo                          ProductName  \
# 0        581482  12/9/2019     22485        Set Of 2 Wooden Market Crates
# 1        581475  12/9/2019     22596  Christmas Star Wish List Chalkboard
# 2        581475  12/9/2019     23235             Storage Tin Vintage Leaf
# 3        581475  12/9/2019     23272    Tree T-Light Holder Willie Winkie
# 4        581475  12/9/2019     23239    Set Of 4 Knick Knack Tins Poppies
#
#    Price  Quantity  CustomerNo         Country
# 0  21.47      12.0     17490.0  United Kingdom
# 1  10.65      36.0     13069.0  United Kingdom
# 2  11.53      12.0     13069.0  United Kingdom
# 3  10.65      12.0     13069.0  United Kingdom
# 4  11.94       6.0     13069.0  United Kingdom

# %%
# Sampling the data based on tails (5 least ranks)
df.tail()
# Out:
#        TransactionNo        Date ProductNo                     ProductName  \
# 116923        573300  10/28/2019     22095            Lads Only Tissue Box
# 116924        573300  10/28/2019     22093             Motoring Tissue Box
# 116925        573300  10/28/2019     21169  You're Confusing Me Metal Sign
# 116926        573300  10/28/2019     22412  Metal Sign Neighbourhood Witch
# 116927            57         NaN       NaN                             NaN
#
#         Price  Quantity  CustomerNo         Country
# 116923  10.65       6.0     16049.0  United Kingdom
# 116924  10.65       4.0     16049.0  United Kingdom
# 116925  11.98       1.0     16049.0  United Kingdom
# 116926  12.40       1.0     16049.0  United Kingdom
# 116927    NaN       NaN         NaN             NaN

# %% [markdown]
# # Understanding The Data
#
# #### Based on the source of the data, we can describe the dataset to understanding the meaning of the data. Each data can be describe as follow :
#  1. TransactionNo (categorical): a six-digit unique number that defines each transaction. The letter “C” in the code indicates a cancellation.
#
#  2. Date (numeric): the date when each transaction was generated.
#
#  3. ProductNo (categorical): a five or six-digit unique character used to identify a specific product.
#
#  4. Product (categorical): product/item name.
#
#  5. Price (numeric): the price of each product per unit in pound sterling (£).
#
#  6. Quantity (numeric): the quantity of each product per transaction. Negative values related to cancelled transactions.
#
#  7. CustomerNo (categorical): a five-digit unique number that defines each customer.
#
#  8. Country (categorical): name of the country where the customer resides.

# %%
# Print the shape of the dataset
df.shape
# Out:
# (116928, 8)

# %%
# Print to describing about the dataset
df.describe()
# Out:
#                Price       Quantity     CustomerNo
# count  116927.000000  116927.000000  116923.000000
# mean       10.227039       8.938577   15250.192434
# std         4.773634     338.409181    1685.218365
# min         5.130000  -80995.000000   12057.000000
# 25%         6.190000       1.000000   13985.000000
# 50%        10.680000       3.000000   15177.000000
# 75%        12.400000      10.000000   16729.000000
# max       594.500000   80995.000000   18287.000000

# %%
# Print to look for info about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116928 entries, 0 to 116927
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   TransactionNo  116928 non-null  object
#  1   Date           116927 non-null  object
#  2   ProductNo      116927 non-null  object
#  3   ProductName    116927 non-null  object
#  4   Price          116927 non-null  float64
#  5   Quantity       116927 non-null  float64
#  6   CustomerNo     116923 non-null  float64
#  7   Country        116927 non-null  object
# dtypes: float64(3), object(5)
# memory usage: 7.1+ MB

# %%
# Print to searching about missing values
print ("Missing Values")
print ("-"*30)
print(df.isnull().sum())
# Out:
# Missing Values
# ------------------------------
# TransactionNo    0
# Date             1
# ProductNo        1
# ProductName      1
# Price            1
# Quantity         1
# CustomerNo       5
# Country          1
# dtype: int64

# %%
# Searching for data duplicates
print ("Data Duplicatioin")
print ("-"*30)
print(df.duplicated(keep=False).sum())
# Out:
# Data Duplicatioin
# ------------------------------
# 2888

# %%
# Check the unique value on Dataset
print("Unique Values")
print("-"*30)
print(df.nunique())
# Out:
# Unique Values
# ------------------------------
# TransactionNo    4343
# Date               37
# ProductNo        2963
# ProductName      2963
# Price             279
# Quantity          299
# CustomerNo       2135
# Country            26
# dtype: int64

# %%
print(f"There's {df['Country'].nunique()} Country in this Dataset")
print("-"*30)
print('Including :', df['Country'].unique())
# Out:
# There's 26 Country in this Dataset
# ------------------------------
# Including : ['United Kingdom' 'Norway' 'Belgium' 'Germany' 'France' 'Austria'
#  'Netherlands' 'EIRE' 'USA' 'Channel Islands' 'Iceland' 'Portugal' 'Spain'
#  'Finland' 'Italy' 'Greece' 'Japan' 'Sweden' 'Denmark' 'Cyprus' 'Malta'
#  'Switzerland' 'Australia' 'Czech Republic' 'Poland' 'Hong Kong' nan]

# %% [markdown]
# From here we learn that :
#
# 1. The dataset contain (536350 rows of transaction, 8 collumns of attributes).
# 2. The 'Date' collumn stored as an object (text), which is not a proper date and time format
# 3. The 'CustomerNo' collumn stored as an float numbers, which can cause ambiguousity
# 4. Total of country that this database have is 38 Country. Which mean this online shop business have transaction across the country in the world.
# 5. Some data have missing values, including the CustomerNo, which is unexpected. Every transaction mustly have a CustomerNo in there.
# 6. In Quantity collumn, there have negative values. It can cause ambigousity to.
# 7. In Transaction collumn, we must remember that if theres have letter "C" in the first value. That indicate cancellation.

# %% [markdown]
# # Data Cleaning

# %%
# Display the rows in the 'CostumerNo' collumn:
rows_in_costumerno_missing = df[df['CustomerNo'].isnull()]
print ("Rows CostumerNo With Missing Values")
rows_in_costumerno_missing.head()
# Out:
# Rows CostumerNo With Missing Values
#        TransactionNo       Date ProductNo                      ProductName  \
# 6511         C581406  12/8/2019    46000M     Polyester Filler Pad 45x45cm
# 6512         C581406  12/8/2019    46000S     Polyester Filler Pad 40x40cm
# 90098        C575153  11/8/2019     22947       Wooden Advent Calendar Red
# 102671       C574288  11/3/2019     22178  Victorian Glass Hanging T-Light
# 116927            57        NaN       NaN                              NaN
#
#         Price  Quantity  CustomerNo         Country
# 6511     6.19    -240.0         NaN  United Kingdom
# 6512     6.19    -300.0         NaN  United Kingdom
# 90098   44.25      -1.0         NaN  United Kingdom
# 102671  25.37      -1.0         NaN  United Kingdom
# 116927    NaN       NaN         NaN             NaN

# %%
#cleaning the data with missing values
df = df.dropna()
#checking the data
print ("Missing Values")
print ("-"*30)
print(df.isnull().sum())
# Out:
# Missing Values
# ------------------------------
# TransactionNo    0
# Date             0
# ProductNo        0
# ProductName      0
# Price            0
# Quantity         0
# CustomerNo       0
# Country          0
# dtype: int64

# %%
#check if there's duplicates in dataset
print ('Data Duplicates')
print ("-"*30)
print (df.duplicated(keep=False).sum())
# Out:
# Data Duplicates
# ------------------------------
# 2888

# %%
#cleaning the duplicates
df = df.drop_duplicates()

# %%
#checking again if there's duplicates in dataset
print ('Data Duplicates')
print ("-"*30)
print (df.duplicated(keep=False).sum())
# Out:
# Data Duplicates
# ------------------------------
# 0

# %%
#check description of the databased
df.describe()
# Out:
#                Price       Quantity     CustomerNo
# count  115431.000000  115431.000000  115431.000000
# mean       10.223953       9.026735   15243.544966
# std         4.785729     340.590809    1683.860795
# min         5.130000  -80995.000000   12057.000000
# 25%         6.190000       1.000000   13982.000000
# 50%        10.680000       3.000000   15159.000000
# 75%        12.400000      10.000000   16729.000000
# max       594.500000   80995.000000   18287.000000

# %% [markdown]
# > if we look at the database, there have negative value in 'Quantity'. We must clean that
# and make sure that TransactionNo must'nt have 'C' indicator in there (Cancellation).

# %%
# Searching the TransactionNo with 'C' indicators
cancelation = df[df['TransactionNo'].str.startswith('C') & (df['Quantity'] < 0)]

# Print the cancelation rows
print ("Cancelation Orders")
cancelation
# Out:
# Cancelation Orders
#        TransactionNo        Date ProductNo                       ProductName  \
# 1616         C581484   12/9/2019     23843         Paper Craft Little Birdie
# 1617         C581490   12/9/2019     22178   Victorian Glass Hanging T-Light
# 1618         C581490   12/9/2019     23144   Zinc T-Light Holder Stars Small
# 1619         C581568   12/9/2019     21258        Victorian Sewing Box Large
# 1620         C581569   12/9/2019     84978  Hanging Heart Jar T-Light Holder
# ...              ...         ...       ...                               ...
# 115658       C573321  10/30/2019    85040A   S/4 Pink Flower Candles In Bowl
# 115659       C573321  10/30/2019     22553            Plasters In Tin Skulls
# 115660       C573321  10/30/2019     22178   Victorian Glass Hanging T-Light
# 115661       C573321  10/30/2019     23014    Glass Apothecary Bottle Elixir
# 115662       C573321  10/30/2019     48138                Doormat Union Flag
#
#         Price  Quantity  CustomerNo         Country
# 1616     6.19  -80995.0     16446.0  United Kingdom
# 1617     6.19     -12.0     14397.0  United Kingdom
# 1618     6.04     -11.0     14397.0  United Kingdom
# 1619     6.19      -5.0     15311.0  United Kingdom
# 1620     6.19      -1.0     17315.0  United Kingdom
# ...       ...       ...         ...             ...
# 115658  11.94      -1.0     14546.0  United Kingdom
# 115659  11.94      -1.0     14546.0  United Kingdom
# 115660  12.25      -1.0     14546.0  United Kingdom
# 115661  14.30      -1.0     14546.0  United Kingdom
# 115662  18.71      -1.0     14546.0  United Kingdom
#
# [1363 rows x 8 columns]

# %% [markdown]
# let's go delete them because there are invalid values

# %%
# Delete Cancelation Transaction based on Quantity below 0
df = df[df['Quantity'] > 0]

# %%
# Checking the databased again
df.describe()
# Out:
#                Price       Quantity     CustomerNo
# count  114068.000000  114068.000000  114068.000000
# mean       10.216911       9.969895   15246.123856
# std         4.754435     244.638106    1683.062449
# min         5.130000       1.000000   12057.000000
# 25%         6.190000       1.000000   13985.000000
# 50%        10.680000       3.000000   15159.000000
# 75%        12.400000      10.000000   16729.000000
# max       594.500000   80995.000000   18287.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114068 entries, 0 to 116926
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   TransactionNo  114068 non-null  object
#  1   Date           114068 non-null  object
#  2   ProductNo      114068 non-null  object
#  3   ProductName    114068 non-null  object
#  4   Price          114068 non-null  float64
#  5   Quantity       114068 non-null  float64
#  6   CustomerNo     114068 non-null  float64
#  7   Country        114068 non-null  object
# dtypes: float64(3), object(5)
# memory usage: 7.8+ MB

# %%
# Changing the type 'Date' to datetime
df['Date'] = pd.to_datetime(df['Date'])

# %%
# Changing the data type 'CustomerNo' and 'TransactionId' into integer
df['CustomerNo'] = df['CustomerNo'].astype(int)
df['TransactionNo'] = df['TransactionNo'].astype(int)

# %%
#Let's check it again
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114068 entries, 0 to 116926
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   TransactionNo  114068 non-null  int64
#  1   Date           114068 non-null  datetime64[ns]
#  2   ProductNo      114068 non-null  object
#  3   ProductName    114068 non-null  object
#  4   Price          114068 non-null  float64
#  5   Quantity       114068 non-null  float64
#  6   CustomerNo     114068 non-null  int64
#  7   Country        114068 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(3)
# memory usage: 7.8+ MB

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# First we need to set the time of database for being analyze

# %%
# Setting the date and time
start_date = df.Date.min()
end_date = df.Date.max()
period = end_date - start_date

print("Start:", start_date)
print("End:", end_date)
print("Period:", period)
# Out:
# Start: 2019-10-28 00:00:00
# End: 2019-12-09 00:00:00
# Period: 42 days 00:00:00

# %%
# Get orders counts of countries
countries = df['Country'].value_counts()

# Prepare data dictionary for choropleth map
data = dict(type='choropleth', locations=countries.index, locationmode='country names', z=countries, text=countries.index, colorbar={'title': 'Order num.'})

# Define layout for choropleth map
layout = dict(title='Total number of orders per country', geo=dict(showframe=True, projection={'type': 'mercator'}), width=1000, height=1000)

# Create choropleth map figure
choromap = go.Figure(data=[data], layout=layout)

# Display the choropleth map
iplot(choromap, validate=False)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9664e268-f530-4360-8572-4ba3603351b5" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9664e268-f530-4360-8572-4ba3603351b5")) {                    Plotly.newPlot(                        "9664e268-f530-4360-8572-4ba3603351b5",                        [{"colorbar":{"title":{"text":"Order num."}},"locationmode":"country names","locations":["United Kingdom","France","EIRE","Germany","Iceland","Austria","Spain","Belgium","Netherlands","Norway","Portugal","Switzerland","Italy","Denmark","Cyprus","Sweden","Finland","Channel Islands","USA","Australia","Greece","Japan","Poland","Malta","Hong Kong"],"text":["United Kingdom","France","EIRE","Germany","Iceland","Austria","Spain","Belgium","Netherlands","Norway","Portugal","Switzerland","Italy","Denmark","Cyprus","Sweden","Finland","Channel Islands","USA","Australia","Greece","Japan","Poland","Malta","Hong Kong"],"z":[105237,1968,1432,1416,661,634,469,392,304,251,237,221,202,93,93,88,88,77,51,43,35,32,26,11,7],"type":"choropleth"}],                        {"geo":{"projection":{"type":"mercator"},"showframe":true},"height":1000,"title":{"text":"Total number of orders per country"},"width":1000,"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay", ...

# %%
# Creating Revenue Collumn
df['Revenue'] = df['Price'] * df['Quantity']
df.sample()
# Out:
#        TransactionNo       Date ProductNo                    ProductName  \
# 45095         578551 2019-11-24    84029E  Red Woolly Hottie White Heart
#
#        Price  Quantity  CustomerNo         Country  Revenue
# 45095   6.04       4.0       12937  United Kingdom    24.16

# %%
# Grouping Country and Revenue
top_revenue = df.groupby(['Country'])['Revenue'].sum().reset_index()
top_revenue = top_revenue.sort_values(by=['Revenue'], ascending = False)

# Creating Diagram Bar to determine which country has top revenue
fig = px.bar(top_revenue.head(5), x='Country', y='Revenue', color='Revenue', title='Highest Revenue Countries')
fig.update_xaxes(title='Country')
fig.update_yaxes(title='Revenue')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a148ce10-9d3e-4c82-87a1-4703d390ff4e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a148ce10-9d3e-4c82-87a1-4703d390ff4e")) {                    Plotly.newPlot(                        "a148ce10-9d3e-4c82-87a1-4703d390ff4e",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}\u003cbr\u003eRevenue=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[9767350.94,267034.02,221280.22,215890.66,172176.13],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["United Kingdom","France","Netherlands","EIRE","Germany"],"xaxis":"x","y":[9767350.94,267034.02,221280.22,215890.66,172176.13],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillm ...

# %% [markdown]
# as you guys can see... the highest revenue in this databased is United Kingdom with **52346795**.

# %%
# Searching Total Product in Database
print('Total Product on this Database:\n' + str(df['ProductName'].nunique()))
# Out:
# Total Product on this Database:
# 2960

# %%
# Grouping ProductName with Quantity
top_product = df.groupby(['ProductName'])['Quantity'].sum().reset_index()
top_product = top_product.sort_values(by=['Quantity'], ascending = False)

# Creating Diagram Bar to determine which country has top revenue
fig = px.bar(top_product.head(10), x='ProductName', y='Quantity', color='Quantity', title='Top Product Based on Quantity')
fig.update_xaxes(title='Product Name')
fig.update_yaxes(title='Total Quantity Sold')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="03bd9d86-6f37-467a-a274-04ff3e129bc6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("03bd9d86-6f37-467a-a274-04ff3e129bc6")) {                    Plotly.newPlot(                        "03bd9d86-6f37-467a-a274-04ff3e129bc6",                        [{"alignmentgroup":"True","hovertemplate":"ProductName=%{x}\u003cbr\u003eQuantity=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[80995.0,21345.0,21081.0,12651.0,10203.0,7180.0,6982.0,6866.0,6141.0,6104.0],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Paper Craft Little Birdie","Rabbit Night Light","Popcorn Holder","Asstd Design 3d Paper Stickers","Paper Chain Kit 50'S Christmas","Jumbo Bag Red Retrospot","Assorted Colour Bird Ornament","Wooden Star Christmas Scandinavian","Cream Hanging Heart T-Light Holder","Wooden Heart Christmas Scandinavian"],"xaxis":"x","y":[80995.0,21345.0,21081.0,12651.0,10203.0,7180.0,6982.0,6866.0,6141.0,6104.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"typ ...

# %%
# Grouping ProductName with Revenue
top_product = df.groupby(['ProductName'])['Revenue'].sum().reset_index()
top_product = top_product.sort_values(by=['Revenue'], ascending = False)

# Creating Diagram Bar to determine which country has top revenue
fig = px.bar(top_product.head(10), x='ProductName', y='Revenue', color='Revenue', title='Top Product Based on Revenue')
fig.update_xaxes(title='Product Name')
fig.update_yaxes(title='Total Revenue')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bfcdb252-6086-481a-8acd-fd2bd1e862b7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bfcdb252-6086-481a-8acd-fd2bd1e862b7")) {                    Plotly.newPlot(                        "bfcdb252-6086-481a-8acd-fd2bd1e862b7",                        [{"alignmentgroup":"True","hovertemplate":"ProductName=%{x}\u003cbr\u003eRevenue=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[1002718.1000000001,212965.59,189366.72,111646.52,78403.36,69775.68000000001,67661.3,60845.36,55742.26,54815.25],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Paper Craft Little Birdie","Rabbit Night Light","Popcorn Holder","Paper Chain Kit 50'S Christmas","Asstd Design 3d Paper Stickers","Assorted Colour Bird Ornament","Cream Hanging Heart T-Light Holder","Wooden Star Christmas Scandinavian","Wooden Heart Christmas Scandinavian","World War 2 Gliders Asstd Designs"],"xaxis":"x","y":[1002718.1000000001,212965.59,189366.72,111646.52,78403.36,69775.68000000001,67661.3,60845.36,55742.26,54815.25],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fi ...

# %%
# Searching Total Customer in Database
print('Total Customer on this Database:\n' + str(df['CustomerNo'].nunique()))
# Out:
# Total Customer on this Database:
# 2099

# %%
# Grouping CustomerNo with Quantity
top_customer_by_quantity = df.groupby(['CustomerNo'])['Quantity'].sum().reset_index()
top_customer_by_quantity = top_customer_by_quantity.sort_values(by=['Quantity'], ascending = False)

# Horizontal bar plot for top customers by quantity
fig_customer_quantity = px.bar(top_customer_by_quantity.head(10), x="Quantity", y="CustomerNo", color="Quantity", orientation='h', title="Top Customers according to Product Quantity Sold")
fig_customer_quantity.update_xaxes(title="Quantity")
fig_customer_quantity.update_yaxes(title="CustomerNo", type = 'category')
fig_customer_quantity.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b73dd5d5-93bf-4480-9525-3c297fd845ab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b73dd5d5-93bf-4480-9525-3c297fd845ab")) {                    Plotly.newPlot(                        "b73dd5d5-93bf-4480-9525-3c297fd845ab",                        [{"alignmentgroup":"True","hovertemplate":"Quantity=%{marker.color}\u003cbr\u003eCustomerNo=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[80995.0,26268.0,17096.0,16951.0,14149.0,13956.0,12540.0,10884.0,10701.0,10547.0],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[80995.0,26268.0,17096.0,16951.0,14149.0,13956.0,12540.0,10884.0,10701.0,10547.0],"xaxis":"x","y":[16446,14646,17511,14911,15941,14365,13256,18102,17450,14096],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"}," ...

# %%
# Grouping CustomerNo with Revenue
top_customer_by_revenue = df.groupby(['CustomerNo'])['Revenue'].sum().reset_index()
top_customer_by_revenue = top_customer_by_revenue.sort_values(by=['Revenue'], ascending = False)

# Horizontal bar plot for top customers by quantity
fig_customer_revenue = px.bar(top_customer_by_revenue.head(10), x="Revenue", y="CustomerNo", color="Revenue", orientation='h', title="Top Customers according to Revenue")
fig_customer_revenue.update_xaxes(title="Revenue")
fig_customer_revenue.update_yaxes(title="CustomerNo", type = 'category')
fig_customer_revenue.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9392cea3-167f-43ba-9141-0e411e039fea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9392cea3-167f-43ba-9141-0e411e039fea")) {                    Plotly.newPlot(                        "9392cea3-167f-43ba-9141-0e411e039fea",                        [{"alignmentgroup":"True","hovertemplate":"Revenue=%{marker.color}\u003cbr\u003eCustomerNo=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[1002718.1000000001,217679.58000000002,184880.85,184148.76,166108.27,125960.05,116496.23,116442.04,99152.24,91486.0],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[1002718.1000000001,217679.58000000002,184880.85,184148.76,166108.27,125960.05,116496.23,116442.04,99152.24,91486.0],"xaxis":"x","y":[16446,14646,15941,14365,14911,17511,17450,18102,14096,16684],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}], ...
